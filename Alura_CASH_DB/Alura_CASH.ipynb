# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Challenge Dados 1/Challenge-Data-Science-1ed/exportacao.csv")

# %%
dataset.head(100)
# Out:
#        ID_PESSOAL  ID_EMPRESTIMO   ID_HISTORICO  IDADE  SALARIO_ANUAL  \
# 0   F9a6bBd9-Xe2o  8HuvzhAq-k7Xi  L42AQtMx-SEGR   27.0        68000.0
# 1   RSQpYv0W-D6Oo  PDpdl2hQ-Sszr  oZ2iPvfD-HdIo   24.0        12600.0
# 2   bRYeof0L-cqHI  0T2YFLWb-IZze  0Y1a64ag-4RLW   30.0       100000.0
# 3   d0YRlkdZ-nuLT  xzTEiD3e-BbFZ  Z5LA433k-5vqf   28.0        83000.0
# 4   njGBnugm-85Dv  QKDlpIm7-sqMC  ObEkaKZr-9MDa   30.0       110400.0
# ..            ...            ...            ...    ...            ...
# 95  iFUqbt43-oZiu  6SAwXNCZ-MOhE  RDZA7Kmj-ItZU   26.0       110000.0
# 96  6gvkMnO6-uuqJ  neElFqPi-j5eC  KvWZcfUs-8W1E   27.0        55200.0
# 97  NNIllnbK-lPGm  vs4HF7wi-ml41  9tpFQq96-b5Po   35.0        95028.0
# 98  YgZhwN7W-QXry  QkKyU4Q5-aAhz  d1MthkRf-8j00   22.0        48000.0
# 99  D00TwgLh-krqw  slZMKNI7-WZIv  48S099Y1-DNNM   22.0        71004.0
#
#    PROP_SITUACAO  TEMPO_TRAB INTENCAO_EMPRESTIMO GRAU_EMPRESTIMO  VALOR_TOTAL  \
# ...
